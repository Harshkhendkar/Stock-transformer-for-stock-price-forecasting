# %%
# !git clone https://github.com/SJTU-DMTai/MASTER.git
# Out:
# Cloning into 'MASTER'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 66 (delta 22), reused 16 (delta 16), pack-reused 39 (from 1)
# Receiving objects: 100% (66/66), 15.59 MiB | 9.99 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# %cd /content/MASTER/
# Out:
# /content/MASTER

# %%
# !pip install pandas==1.5.3 torch==1.11.0

# Install pyqlib
# !pip install pyqlib
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement torch==1.11.0 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0)
# ERROR: No matching distribution found for torch==1.11.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 121.5 MB/s eta 0:00:00
# ...

# %%
# !python main.py
# Out:
# Data Loaded.
# Epoch 0, train_loss 1.030469, valid ic 0.0717, icir 0.604, rankic 0.0798, rankicir 0.660.
# Epoch 1, train_loss 0.998906, valid ic 0.0880, icir 0.737, rankic 0.0969, rankicir 0.728.
# Epoch 2, train_loss 0.992917, valid ic 0.1025, icir 0.841, rankic 0.1012, rankicir 0.728.
# Epoch 3, train_loss 0.991003, valid ic 0.1058, icir 0.900, rankic 0.1104, rankicir 0.845.
# Epoch 4, train_loss 0.989558, valid ic 0.1069, icir 0.831, rankic 0.1104, rankicir 0.792.
# Epoch 5, train_loss 0.988324, valid ic 0.1076, icir 0.844, rankic 0.1072, rankicir 0.779.
# Epoch 6, train_loss 0.987535, valid ic 0.1028, icir 0.813, rankic 0.1070, rankicir 0.811.
# Epoch 7, train_loss 0.986504, valid ic 0.0996, icir 0.762, rankic 0.1065, rankicir 0.816.
# Epoch 8, train_loss 0.985824, valid ic 0.1061, icir 0.886, rankic 0.1041, rankicir 0.824.
# Epoch 9, train_loss 0.985123, valid ic 0.1050, icir 0.865, rankic 0.1069, rankicir 0.891.
# ...

# %%
# !python main.py
# Out:
# Data Loaded.
# Model Loaded from model/csi300_opensource_0.pkl
# {'IC': np.float64(0.05618407679901079), 'ICIR': np.float64(0.3962106285108077), 'RIC': np.float64(0.05413422105985025), 'RICIR': np.float64(0.3733990257692071)}
# IC: 0.0562 pm 0.0000
# ICIR: 0.3962 pm 0.0000
# RIC: 0.0541 pm 0.0000
# RICIR: 0.3734 pm 0.0000

# %%
# !python main.py
# Out:
# Data Loaded.
# Model Loaded from model/csi300_opensource_4.pkl
# {'IC': np.float64(0.06360807679317551), 'ICIR': np.float64(0.42805790413145406), 'RIC': np.float64(0.07095647253847401), 'RICIR': np.float64(0.4695724936269201)}
# IC: 0.0636 pm 0.0000
# ICIR: 0.4281 pm 0.0000
# RIC: 0.0710 pm 0.0000
# RICIR: 0.4696 pm 0.0000

# %%
# !python main.py
# Out:
# Data Loaded.
# Model Loaded from model/csi300_opensource_0t.pkl
# {'IC': np.float64(0.06406885648151929), 'ICIR': np.float64(0.4387005294055525), 'RIC': np.float64(0.06748040074326789), 'RICIR': np.float64(0.4474965831163518)}
# IC: 0.0641 pm 0.0000
# ICIR: 0.4387 pm 0.0000
# RIC: 0.0675 pm 0.0000
# RICIR: 0.4475 pm 0.0000

# %%
# !python main.py
# Out:
# Data Loaded.
# Epoch 0, train_loss 1.026909, valid ic 0.0626, icir 0.497, rankic 0.0923, rankicir 0.738.
# Epoch 1, train_loss 0.993428, valid ic 0.0843, icir 0.704, rankic 0.1070, rankicir 0.850.
# Epoch 2, train_loss 0.988813, valid ic 0.0957, icir 0.791, rankic 0.1114, rankicir 0.861.
# Epoch 3, train_loss 0.986517, valid ic 0.0759, icir 0.599, rankic 0.1073, rankicir 0.834.
# Epoch 4, train_loss 0.984826, valid ic 0.0777, icir 0.650, rankic 0.1068, rankicir 0.860.
# Epoch 5, train_loss 0.983210, valid ic 0.0870, icir 0.749, rankic 0.1126, rankicir 0.926.
# Epoch 6, train_loss 0.982083, valid ic 0.0784, icir 0.647, rankic 0.1101, rankicir 0.880.
# Epoch 7, train_loss 0.980851, valid ic 0.0620, icir 0.508, rankic 0.1009, rankicir 0.819.
# Epoch 8, train_loss 0.979879, valid ic 0.0781, icir 0.694, rankic 0.1097, rankicir 0.942.
# Epoch 9, train_loss 0.978893, valid ic 0.0695, icir 0.586, rankic 0.1056, rankicir 0.870.
# Model Trained.
# Seed: 0 time cost : 991.07 sec
# ...
