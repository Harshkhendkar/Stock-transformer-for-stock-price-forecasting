# %%
# !git clone https://github.com/SJTU-DMTai/MASTER.git
# Out:
# Cloning into 'MASTER'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 66 (delta 22), reused 16 (delta 16), pack-reused 39 (from 1)
# Receiving objects: 100% (66/66), 15.59 MiB | 16.10 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# Install specific versions
# !pip install pandas==1.5.3 torch==1.11.0

# Install pyqlib
# !pip install pyqlib

# Clone your repo if needed (assuming you have the code in a GitHub repo)
# !git clone https://github.com/your_username/your_repo_name.git
# %cd your_repo_name

# Download your data (assuming you have a URL)
# Example (replace URL with your own data link):
# !wget YOUR_DATA_URL -O data.zip
# !unzip data.zip -d data/

# Otherwise, upload manually:

# After uploading, manually move your files into `data/` if needed

# Check uploaded files


# Then you can run your main.py
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement torch==1.11.0 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0)
# ERROR: No matching distribution found for torch==1.11.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 79.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 126.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/MASTER/
# Out:
# /content/MASTER

# %%
# !python main.py  #given model test
# Out:
# Data Loaded.
# Model Loaded from model/csi300_opensource_0.pkl
# Epoch: Previously trained.
# {'IC': np.float64(0.06509194276176683), 'ICIR': np.float64(0.4400727246927701), 'RIC': np.float64(0.06845180415854277), 'RICIR': np.float64(0.44896865121615326)}
# IC: 0.0651 pm 0.0000
# ICIR: 0.4401 pm 0.0000
# RIC: 0.0685 pm 0.0000
# RICIR: 0.4490 pm 0.0000

# %%
# !python main.py #gru 300
# Out:
# Data Loaded.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn(
# Epoch 0, train_loss 1.006602, valid ic 0.0867, icir 0.560, rankic 0.0935, rankicir 0.675.
# Epoch 1, train_loss 0.988268, valid ic 0.0966, icir 0.756, rankic 0.1030, rankicir 0.810.
# Epoch 2, train_loss 0.984683, valid ic 0.1055, icir 0.780, rankic 0.1069, rankicir 0.813.
# Epoch 3, train_loss 0.982478, valid ic 0.0946, icir 0.683, rankic 0.1007, rankicir 0.774.
# Epoch 4, train_loss 0.980292, valid ic 0.1048, icir 0.766, rankic 0.1106, rankicir 0.830.
# Epoch 5, train_loss 0.978605, valid ic 0.0924, icir 0.648, rankic 0.0944, rankicir 0.712.
# Epoch 6, train_loss 0.976800, valid ic 0.0916, icir 0.652, rankic 0.0951, rankicir 0.714.
# ...
